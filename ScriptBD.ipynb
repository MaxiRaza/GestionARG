-- %% [markdown]
-- # [GestionARG]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [GestionARG]    Script Date: 27/04/2021 3:41:39 ******/
CREATE DATABASE [GestionARG]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'GestionARG', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\GestionARG.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'GestionARG_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\GestionARG_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [GestionARG] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [GestionARG].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [GestionARG] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [GestionARG] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [GestionARG] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [GestionARG] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [GestionARG] SET ARITHABORT OFF 
GO
ALTER DATABASE [GestionARG] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [GestionARG] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [GestionARG] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [GestionARG] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [GestionARG] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [GestionARG] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [GestionARG] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [GestionARG] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [GestionARG] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [GestionARG] SET  DISABLE_BROKER 
GO
ALTER DATABASE [GestionARG] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [GestionARG] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [GestionARG] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [GestionARG] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [GestionARG] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [GestionARG] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [GestionARG] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [GestionARG] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [GestionARG] SET  MULTI_USER 
GO
ALTER DATABASE [GestionARG] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [GestionARG] SET DB_CHAINING OFF 
GO
ALTER DATABASE [GestionARG] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [GestionARG] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [GestionARG] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [GestionARG] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [maxi]

-- %%
USE [GestionARG]
GO

-- %%
/****** Object:  User [maxi]    Script Date: 27/04/2021 3:41:39 ******/
CREATE USER [maxi] FOR LOGIN [maxi] WITH DEFAULT_SCHEMA=[dbo]
GO

-- %% [markdown]
-- # [dbo].[Categorias]

-- %%
/****** Object:  Table [dbo].[Categorias]    Script Date: 27/04/2021 3:41:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Categorias](
	[id_categoria] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [nvarchar](50) NULL,
 CONSTRAINT [PK_Categorias] PRIMARY KEY CLUSTERED 
(
	[id_categoria] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Clasificaciones]

-- %%
/****** Object:  Table [dbo].[Clasificaciones]    Script Date: 27/04/2021 3:41:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Clasificaciones](
	[id_clasificacion] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [nvarchar](50) NULL,
 CONSTRAINT [PK_Clasificaciones] PRIMARY KEY CLUSTERED 
(
	[id_clasificacion] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Clientes]

-- %%
/****** Object:  Table [dbo].[Clientes]    Script Date: 27/04/2021 3:41:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Clientes](
	[id_cliente] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [nvarchar](50) NULL,
	[apellido] [nvarchar](50) NULL,
	[fecha_nac] [date] NULL,
	[documento] [bigint] NULL,
	[id_contacto] [int] NULL,
	[id_tipo_cliente] [int] NULL,
 CONSTRAINT [PK_Clientes] PRIMARY KEY CLUSTERED 
(
	[id_cliente] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Contactos]

-- %%
/****** Object:  Table [dbo].[Contactos]    Script Date: 27/04/2021 3:41:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Contactos](
	[id_contacto] [int] IDENTITY(1,1) NOT NULL,
	[telefono] [nvarchar](50) NULL,
	[correo] [nvarchar](50) NULL,
 CONSTRAINT [PK_Contactos] PRIMARY KEY CLUSTERED 
(
	[id_contacto] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Depositos]

-- %%
/****** Object:  Table [dbo].[Depositos]    Script Date: 27/04/2021 3:41:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Depositos](
	[id_deposito] [int] IDENTITY(1,1) NOT NULL,
	[ubicacion] [nvarchar](50) NULL,
 CONSTRAINT [PK_Depositos] PRIMARY KEY CLUSTERED 
(
	[id_deposito] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Detalle_Encargos]

-- %%
/****** Object:  Table [dbo].[Detalle_Encargos]    Script Date: 27/04/2021 3:41:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Detalle_Encargos](
	[id_detalle_encargo] [int] IDENTITY(1,1) NOT NULL,
	[cantidad] [float] NULL,
	[importe] [real] NULL,
	[id_producto] [int] NULL,
	[id_encargo] [int] NULL,
 CONSTRAINT [PK_Detalle_Encargos] PRIMARY KEY CLUSTERED 
(
	[id_detalle_encargo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Detalle_Facturas]

-- %%
/****** Object:  Table [dbo].[Detalle_Facturas]    Script Date: 27/04/2021 3:41:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Detalle_Facturas](
	[id_detalle_factura] [int] IDENTITY(1,1) NOT NULL,
	[cantidad] [float] NULL,
	[importe] [real] NULL,
	[id_factura] [int] NULL,
	[id_producto] [int] NULL,
 CONSTRAINT [PK_Detalle_Facturas] PRIMARY KEY CLUSTERED 
(
	[id_detalle_factura] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Encargos]

-- %%
/****** Object:  Table [dbo].[Encargos]    Script Date: 27/04/2021 3:41:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Encargos](
	[id_encargo] [int] IDENTITY(1,1) NOT NULL,
	[fecha] [datetime] NULL,
	[id_proveedor] [int] NULL,
 CONSTRAINT [PK_Encargos] PRIMARY KEY CLUSTERED 
(
	[id_encargo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Facturas]

-- %%
/****** Object:  Table [dbo].[Facturas]    Script Date: 27/04/2021 3:41:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Facturas](
	[id_factura] [int] IDENTITY(1,1) NOT NULL,
	[fecha] [datetime] NULL,
	[descuento] [real] NULL,
	[id_sucursal] [int] NULL,
	[id_cliente] [int] NULL,
	[id_usuario] [int] NULL,
	[id_forma_de_pago] [int] NULL,
 CONSTRAINT [PK_Facturas] PRIMARY KEY CLUSTERED 
(
	[id_factura] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Formas_de_Pagos]

-- %%
/****** Object:  Table [dbo].[Formas_de_Pagos]    Script Date: 27/04/2021 3:41:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Formas_de_Pagos](
	[id_forma_de_pago] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [nvarchar](50) NULL,
 CONSTRAINT [PK_Formas_de_Pagos] PRIMARY KEY CLUSTERED 
(
	[id_forma_de_pago] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Marcas]

-- %%
/****** Object:  Table [dbo].[Marcas]    Script Date: 27/04/2021 3:41:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Marcas](
	[id_marca] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [nvarchar](50) NULL,
 CONSTRAINT [PK_Marcas] PRIMARY KEY CLUSTERED 
(
	[id_marca] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Productos]

-- %%
/****** Object:  Table [dbo].[Productos]    Script Date: 27/04/2021 3:41:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Productos](
	[id_producto] [int] IDENTITY(1,1) NOT NULL,
	[codigo] [nvarchar](50) NULL,
	[nombre] [nvarchar](50) NULL,
	[fecha_fab] [datetime] NULL,
	[fecha_ven] [datetime] NULL,
	[precio] [real] NULL,
	[descripcion] [nvarchar](50) NULL,
	[id_categoria] [int] NULL,
	[stock] [float] NULL,
	[id_marca] [int] NULL,
	[id_deposito] [int] NULL,
 CONSTRAINT [PK_Productos] PRIMARY KEY CLUSTERED 
(
	[id_producto] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Proveedores]

-- %%
/****** Object:  Table [dbo].[Proveedores]    Script Date: 27/04/2021 3:41:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Proveedores](
	[id_proveedor] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [nvarchar](50) NULL,
	[cuit] [bigint] NULL,
	[direccion] [nvarchar](50) NULL,
	[id_contacto] [int] NULL,
	[id_tipo_proveedor] [int] NULL,
	[id_clasificacion] [int] NULL,
 CONSTRAINT [PK_Proveedores] PRIMARY KEY CLUSTERED 
(
	[id_proveedor] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Roles]

-- %%
/****** Object:  Table [dbo].[Roles]    Script Date: 27/04/2021 3:41:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Roles](
	[id_rol] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [nvarchar](50) NULL,
 CONSTRAINT [PK_Roles] PRIMARY KEY CLUSTERED 
(
	[id_rol] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Sucursales]

-- %%
/****** Object:  Table [dbo].[Sucursales]    Script Date: 27/04/2021 3:41:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Sucursales](
	[id_sucursal] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [nvarchar](50) NULL,
	[direccion] [nvarchar](50) NULL,
 CONSTRAINT [PK_Sucursales] PRIMARY KEY CLUSTERED 
(
	[id_sucursal] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Tipo_Clientes]

-- %%
/****** Object:  Table [dbo].[Tipo_Clientes]    Script Date: 27/04/2021 3:41:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Tipo_Clientes](
	[id_tipo_cliente] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [nvarchar](50) NULL,
 CONSTRAINT [PK_Tipo_Clientes] PRIMARY KEY CLUSTERED 
(
	[id_tipo_cliente] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Tipo_Proveedores]

-- %%
/****** Object:  Table [dbo].[Tipo_Proveedores]    Script Date: 27/04/2021 3:41:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Tipo_Proveedores](
	[id_tipo_proveedor] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [nvarchar](50) NULL,
 CONSTRAINT [PK_Tipo_Proveedores] PRIMARY KEY CLUSTERED 
(
	[id_tipo_proveedor] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Usuarios]

-- %%
/****** Object:  Table [dbo].[Usuarios]    Script Date: 27/04/2021 3:41:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Usuarios](
	[id_usuario] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [nvarchar](50) NULL,
	[apellido] [nvarchar](50) NULL,
	[documento] [bigint] NULL,
	[fecha_nac] [date] NULL,
	[direccion] [nvarchar](50) NULL,
	[id_rol] [int] NULL,
	[id_contacto] [int] NULL,
 CONSTRAINT [PK_Usuarios] PRIMARY KEY CLUSTERED 
(
	[id_usuario] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_Clientes_Contactos]

-- %%
ALTER TABLE [dbo].[Clientes]  WITH CHECK ADD  CONSTRAINT [FK_Clientes_Contactos] FOREIGN KEY([id_contacto])
REFERENCES [dbo].[Contactos] ([id_contacto])
GO
ALTER TABLE [dbo].[Clientes] CHECK CONSTRAINT [FK_Clientes_Contactos]
GO

-- %% [markdown]
-- # [FK_Clientes_Tipo_Clientes]

-- %%
ALTER TABLE [dbo].[Clientes]  WITH CHECK ADD  CONSTRAINT [FK_Clientes_Tipo_Clientes] FOREIGN KEY([id_tipo_cliente])
REFERENCES [dbo].[Tipo_Clientes] ([id_tipo_cliente])
GO
ALTER TABLE [dbo].[Clientes] CHECK CONSTRAINT [FK_Clientes_Tipo_Clientes]
GO

-- %% [markdown]
-- # [FK_Detalle_Encargos_Encargos]

-- %%
ALTER TABLE [dbo].[Detalle_Encargos]  WITH CHECK ADD  CONSTRAINT [FK_Detalle_Encargos_Encargos] FOREIGN KEY([id_encargo])
REFERENCES [dbo].[Encargos] ([id_encargo])
GO
ALTER TABLE [dbo].[Detalle_Encargos] CHECK CONSTRAINT [FK_Detalle_Encargos_Encargos]
GO

-- %% [markdown]
-- # [FK_Detalle_Encargos_Productos]

-- %%
ALTER TABLE [dbo].[Detalle_Encargos]  WITH CHECK ADD  CONSTRAINT [FK_Detalle_Encargos_Productos] FOREIGN KEY([id_producto])
REFERENCES [dbo].[Productos] ([id_producto])
GO
ALTER TABLE [dbo].[Detalle_Encargos] CHECK CONSTRAINT [FK_Detalle_Encargos_Productos]
GO

-- %% [markdown]
-- # [FK_Detalle_Facturas_Facturas]

-- %%
ALTER TABLE [dbo].[Detalle_Facturas]  WITH CHECK ADD  CONSTRAINT [FK_Detalle_Facturas_Facturas] FOREIGN KEY([id_factura])
REFERENCES [dbo].[Facturas] ([id_factura])
GO
ALTER TABLE [dbo].[Detalle_Facturas] CHECK CONSTRAINT [FK_Detalle_Facturas_Facturas]
GO

-- %% [markdown]
-- # [FK_Detalle_Facturas_Productos]

-- %%
ALTER TABLE [dbo].[Detalle_Facturas]  WITH CHECK ADD  CONSTRAINT [FK_Detalle_Facturas_Productos] FOREIGN KEY([id_producto])
REFERENCES [dbo].[Productos] ([id_producto])
GO
ALTER TABLE [dbo].[Detalle_Facturas] CHECK CONSTRAINT [FK_Detalle_Facturas_Productos]
GO

-- %% [markdown]
-- # [FK_Encargos_Proveedores]

-- %%
ALTER TABLE [dbo].[Encargos]  WITH CHECK ADD  CONSTRAINT [FK_Encargos_Proveedores] FOREIGN KEY([id_proveedor])
REFERENCES [dbo].[Proveedores] ([id_proveedor])
GO
ALTER TABLE [dbo].[Encargos] CHECK CONSTRAINT [FK_Encargos_Proveedores]
GO

-- %% [markdown]
-- # [FK_Facturas_Clientes]

-- %%
ALTER TABLE [dbo].[Facturas]  WITH CHECK ADD  CONSTRAINT [FK_Facturas_Clientes] FOREIGN KEY([id_cliente])
REFERENCES [dbo].[Clientes] ([id_cliente])
GO
ALTER TABLE [dbo].[Facturas] CHECK CONSTRAINT [FK_Facturas_Clientes]
GO

-- %% [markdown]
-- # [FK_Facturas_Formas_de_Pagos]

-- %%
ALTER TABLE [dbo].[Facturas]  WITH CHECK ADD  CONSTRAINT [FK_Facturas_Formas_de_Pagos] FOREIGN KEY([id_forma_de_pago])
REFERENCES [dbo].[Formas_de_Pagos] ([id_forma_de_pago])
GO
ALTER TABLE [dbo].[Facturas] CHECK CONSTRAINT [FK_Facturas_Formas_de_Pagos]
GO

-- %% [markdown]
-- # [FK_Facturas_Sucursales]

-- %%
ALTER TABLE [dbo].[Facturas]  WITH CHECK ADD  CONSTRAINT [FK_Facturas_Sucursales] FOREIGN KEY([id_sucursal])
REFERENCES [dbo].[Sucursales] ([id_sucursal])
GO
ALTER TABLE [dbo].[Facturas] CHECK CONSTRAINT [FK_Facturas_Sucursales]
GO

-- %% [markdown]
-- # [FK_Facturas_Usuarios]

-- %%
ALTER TABLE [dbo].[Facturas]  WITH CHECK ADD  CONSTRAINT [FK_Facturas_Usuarios] FOREIGN KEY([id_usuario])
REFERENCES [dbo].[Usuarios] ([id_usuario])
GO
ALTER TABLE [dbo].[Facturas] CHECK CONSTRAINT [FK_Facturas_Usuarios]
GO

-- %% [markdown]
-- # [FK_Productos_Categorias]

-- %%
ALTER TABLE [dbo].[Productos]  WITH CHECK ADD  CONSTRAINT [FK_Productos_Categorias] FOREIGN KEY([id_categoria])
REFERENCES [dbo].[Categorias] ([id_categoria])
GO
ALTER TABLE [dbo].[Productos] CHECK CONSTRAINT [FK_Productos_Categorias]
GO

-- %% [markdown]
-- # [FK_Productos_Depositos]

-- %%
ALTER TABLE [dbo].[Productos]  WITH CHECK ADD  CONSTRAINT [FK_Productos_Depositos] FOREIGN KEY([id_deposito])
REFERENCES [dbo].[Depositos] ([id_deposito])
GO
ALTER TABLE [dbo].[Productos] CHECK CONSTRAINT [FK_Productos_Depositos]
GO

-- %% [markdown]
-- # [FK_Productos_Marcas]

-- %%
ALTER TABLE [dbo].[Productos]  WITH CHECK ADD  CONSTRAINT [FK_Productos_Marcas] FOREIGN KEY([id_marca])
REFERENCES [dbo].[Marcas] ([id_marca])
GO
ALTER TABLE [dbo].[Productos] CHECK CONSTRAINT [FK_Productos_Marcas]
GO

-- %% [markdown]
-- # [FK_Proveedores_Clasificaciones]

-- %%
ALTER TABLE [dbo].[Proveedores]  WITH CHECK ADD  CONSTRAINT [FK_Proveedores_Clasificaciones] FOREIGN KEY([id_clasificacion])
REFERENCES [dbo].[Clasificaciones] ([id_clasificacion])
GO
ALTER TABLE [dbo].[Proveedores] CHECK CONSTRAINT [FK_Proveedores_Clasificaciones]
GO

-- %% [markdown]
-- # [FK_Proveedores_Contactos]

-- %%
ALTER TABLE [dbo].[Proveedores]  WITH CHECK ADD  CONSTRAINT [FK_Proveedores_Contactos] FOREIGN KEY([id_contacto])
REFERENCES [dbo].[Contactos] ([id_contacto])
GO
ALTER TABLE [dbo].[Proveedores] CHECK CONSTRAINT [FK_Proveedores_Contactos]
GO

-- %% [markdown]
-- # [FK_Proveedores_Tipo_Proveedores]

-- %%
ALTER TABLE [dbo].[Proveedores]  WITH CHECK ADD  CONSTRAINT [FK_Proveedores_Tipo_Proveedores] FOREIGN KEY([id_tipo_proveedor])
REFERENCES [dbo].[Tipo_Proveedores] ([id_tipo_proveedor])
GO
ALTER TABLE [dbo].[Proveedores] CHECK CONSTRAINT [FK_Proveedores_Tipo_Proveedores]
GO

-- %% [markdown]
-- # [FK_Roles_Roles]

-- %%
ALTER TABLE [dbo].[Roles]  WITH CHECK ADD  CONSTRAINT [FK_Roles_Roles] FOREIGN KEY([id_rol])
REFERENCES [dbo].[Roles] ([id_rol])
GO
ALTER TABLE [dbo].[Roles] CHECK CONSTRAINT [FK_Roles_Roles]
GO

-- %% [markdown]
-- # [FK_Usuarios_Contactos]

-- %%
ALTER TABLE [dbo].[Usuarios]  WITH CHECK ADD  CONSTRAINT [FK_Usuarios_Contactos] FOREIGN KEY([id_contacto])
REFERENCES [dbo].[Contactos] ([id_contacto])
GO
ALTER TABLE [dbo].[Usuarios] CHECK CONSTRAINT [FK_Usuarios_Contactos]
GO

-- %% [markdown]
-- # [FK_Usuarios_Roles]

-- %%
ALTER TABLE [dbo].[Usuarios]  WITH CHECK ADD  CONSTRAINT [FK_Usuarios_Roles] FOREIGN KEY([id_rol])
REFERENCES [dbo].[Roles] ([id_rol])
GO
ALTER TABLE [dbo].[Usuarios] CHECK CONSTRAINT [FK_Usuarios_Roles]
GO

-- %% [markdown]
-- # [GestionARG]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [GestionARG] SET  READ_WRITE 
GO
